# %% [markdown]
# # **Perform data wrangling on student mental health dataset**

# %% [markdown]
# ## Import all the necessary liberary

# %% [markdown]
# pandas liberary: It used for data manipulation and analysis.
#
# numPy liberary : It is a powerful Python library for numerical computing.
#
# seaborn liberary : It provides a high-level interface for creating attractive and informative statistical graphics.
#
# matplotlib.pyplot liberary : It provides a MATLAB-like interface for creating basic plots and visualizations.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the dataset in jupyter notebook

# %%
df=pd.read_csv('survey (1).csv')

# %% [markdown]
# ## show the first 5 records of dataset

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %% [markdown]
# ## show the last 5 records of dataset

# %%
df.tail()
# Out:
#                 Timestamp  Age Gender         Country state self_employed  \
# 1254  2015-09-12 11:17:21   26   male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32   Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34   male   United States    CA            No
# 1257  2015-11-30 21:25:06   46      f   United States    NC            No
# 1258  2016-02-01 23:04:31   25   Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 1254             No       Yes            NaN          26-100  ...
# 1255            Yes       Yes          Often          26-100  ...
# 1256            Yes       Yes      Sometimes  More than 1000  ...
# 1257             No        No            NaN         100-500  ...
# 1258            Yes       Yes      Sometimes          26-100  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# ...

# %% [markdown]
# ## show the random 7 samples form the dataset

# %%
df.sample(7)
# Out:
#                 Timestamp  Age        Gender        Country state  \
# 127   2014-08-27 12:34:35   32             M  United States    OR
# 1118  2014-08-30 16:13:40   38          Male  United States    NY
# 85    2014-08-27 12:05:37   31          Male  United States    TX
# 269   2014-08-27 13:55:22   32          Male  United States    CO
# 825   2014-08-28 15:25:39   48  Female (cis)  United States    CA
# 857   2014-08-28 17:02:27   24          Male  United States    TN
# 1063  2014-08-29 12:08:12   25          Male  United States    UT
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 127             No             No       Yes         Rarely         100-500
# 1118            No            Yes       Yes         Rarely  More than 1000
# 85              No             No        No            NaN          26-100
# 269             No             No        No          Never            6-25
# ...

# %% [markdown]
# ## Check the number of rows and columns present in dataset

# %%
df.shape
# Out:
# (1259, 27)

# %% [markdown]
# ## Check the name of all column present in dataset

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country', 'state', 'self_employed',
#        'family_history', 'treatment', 'work_interfere', 'no_employees',
#        'remote_work', 'tech_company', 'benefits', 'care_options',
#        'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence', 'comments'],
#       dtype='object')

# %% [markdown]
# ## The describe() method returns description of the data in the DataFrame

# %%
df.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %% [markdown]
# ## Get the more information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %% [markdown]
# ## Check for null values present or not

# %%
df.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %% [markdown]
# ## Drop the unneccesory columns present in dataset

# %%
df=df.drop(['Timestamp','Country','state','work_interfere','comments','mental_health_interview','phys_health_interview','wellness_program'],axis=1)

# %% [markdown]
# ## Replace all different Gender name into three specific gender

# %%
df['Gender']=df['Gender'].replace(['female','F','Cis Female','Femake','woman','f','Woman','Female (cis)','Female ','femail'],'Female')
df['Gender']=df['Gender'].replace(['Male ','M', 'male', 'm', 'Male-ish', 'maile','Cis Male','Mal','Male (CIS)','male leaning androgynous','Make''Male ', 'Man','cis male','Malr','ostensibly male'],'Male')
df['Gender']=df['Gender'].replace(['Trans-female', 'something kinda male?','queer/she/they', 'non-binary', 'Make', 'Nah', 'All', 'Enby','fluid', 'Genderqueer','Androgyne', 'Agender','cis-female/femme', 'Guy (-ish) ^_^','Trans woman','msle', 'Neuter', 'Female (trans)', 'queer', 'Mail','A little about you', 'p', 'Cis Man','ostensibly male, unsure what that really means' ],'Others')

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Others'], dtype=object)

# %% [markdown]
# ## Fill the null values of column self_employed

# %%
df['self_employed'].fillna('No',inplace=True)

# %% [markdown]
# ## Check for null values present or not

# %%
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# self_employed                0
# family_history               0
# treatment                    0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %% [markdown]
# ## Check the data type of different columns

# %%
df.dtypes
# Out:
# Age                           int64
# Gender                       object
# self_employed                object
# family_history               object
# treatment                    object
# no_employees                 object
# remote_work                  object
# tech_company                 object
# benefits                     object
# care_options                 object
# seek_help                    object
# anonymity                    object
# leave                        object
# mental_health_consequence    object
# phys_health_consequence      object
# coworkers                    object
# supervisor                   object
# mental_vs_physical           object
# obs_consequence              object
# dtype: object

# %% [markdown]
# ## Perform encoding(convet categorical data into the numerical data) in all column expect age column

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()

UnEncoded_col=df.iloc[:, 1:]
for col in UnEncoded_col:
    df[col]=label_encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#    Age  Gender  self_employed  family_history  treatment  no_employees  \
# 0   37       0              0               0          1             4
# 1   44       1              0               0          0             5
# 2   32       1              0               0          0             4
# 3   31       1              0               1          1             2
# 4   31       1              0               0          0             1
#
#    remote_work  tech_company  benefits  care_options  seek_help  anonymity  \
# 0            0             1         2             1          2          2
# 1            0             0         0             0          0          0
# 2            0             1         1             0          1          0
# 3            0             1         1             2          1          1
# 4            1             1         2             0          0          0
#
#    leave  mental_health_consequence  phys_health_consequence  coworkers  \
# ...

# %% [markdown]
# ## Draw the boxplot of Age column

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ## Draw count plot for the different gender according to treatment they required or not

# %%
sns.countplot(x='Gender',hue='treatment',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# ## Distplot of treatment column

# %%
sns.distplot(df['treatment'])
# Out:
# <ipython-input-21-4dff225c2afb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['treatment'])
# <Axes: xlabel='treatment', ylabel='Density'>

# %% [markdown]
# ## Draw heatmap

# %%
c=df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## split the independent and dependent data

# %%
x=df.drop('treatment',axis=1)
y=df['treatment']

# %% [markdown]
# ## Perform training and testing of dataset

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=29)

# %% [markdown]
# ## Check the score of testing ,training of model and accuracy by using Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
training_score=model.score(x_train,y_train)
testing_score=model.score(x_test,y_test)

print("Training score : ",training_score)
print("Testing score : ",testing_score)

predictions=model.predict(x_test)
print(classification_report(y_test,predictions))

print("Accuracy : ",accuracy_score(y_test,predictions))
# Out:
# Training score :  1.0
# Testing score :  0.6944444444444444
#               precision    recall  f1-score   support
#
#            0       0.66      0.74      0.70       121
#            1       0.73      0.66      0.69       131
#
#     accuracy                           0.69       252
#    macro avg       0.70      0.70      0.69       252
# weighted avg       0.70      0.69      0.69       252
#
# Accuracy :  0.6944444444444444

# %%
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Save the trained model to a pickle file
with open("model.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
import pickle

# Load the trained model using pickle
with open("model.pkl", "rb") as f:
    model = pickle.load(f)

# Function to take user input and make predictions
def predict_output(user_input):
   output = model.predict(user_input)
   return output

# Example usage:
Age=int(input("Enter Age : "))
print("\n{Enter 0 for Female\tEnter 1 for Male\tEnter 2 for others }\n")
Gender=int(input("Enter Gender : "))
print("\n{Enter 0 for No\tEnter 1 for Yes}\n")
self_employed=int(input("Enter self_employed : "))
print("\n{Enter 0 for No\tEnter 1 for Yes}\n")
family_history=int(input("Enter family_history : "))
print("\n{Enter 4 for no. of employee between 6-25\nEnter 5 for no. of employee more than 1000\nEnter 2 for no. of employee between 26-100\nEnter 1 for no. of employee between 100-500\nEnter 0 for no. of employee between 1-5\nEnter 3 for no. of employee between 500-1000}\n")
no_employees=int(input("Enter no_employees : "))
print("\n{Enter 0 for no and 1 for yes}\n")
remote_work=int(input("remote_work : "))
print("\n{Enter 0 for no and 1 for yes}\n")
tech_company=int(input("Enter tech_company : "))
print("\n{enter 0 for Don't know\t Enter 1 for No\tEnter 2 for yes}\n")
benefits=int(input("enter benefits : "))
print("\n{enter 0 for no\tEnter 1 for Not sure\tEnter 2 for yes}\n")
care_options=int(input("enter care_options : "))
print("\n{enter 0 for Don't know\tEnter 1 for No\tEnter 2 for yes}\n")
seek_help=int(input("enter seek_help : "))
print("\n{enter 0 for Don't know\tEnter 1 for No\tEnter 2 for yes}\n")
anonymity=int(input("anonymity : "))
print("\n{Enter 0 for Don't know\tEnter 1 for Somewhat difficult\tEnter 2 for Somewhat easy\t enter 3 for Very difficult\tEnter 4 for very easy}\n")
leave=int(input("leave : "))
print("\n{enter 0 for may be\tEnter 1 for No\tEnter 2 for yes}\n")
mental_health_consequence=int(input("mental_health_consequence"))
print("\n{enter 0 for may be\tEnter 1 for No\tEnter 2 for yes}\n")
phys_health_consequence=int(input("phys_health_consequence : "))
print("\n{enter 0 for no\tEnter 1 for some of them\tEnter 2 for yes}\n")
coworkers=int(input("Enter no of coworkers : "))
print("\n{enter 0 for no\tEnter 1 for some of them\tEnter 2 for yes}\n")
supervisor=int(input("Enter supervisor : "))
print("\n{enter 0 for Don't know\tEnter 1 for No\tEnter 2 for yes}\n")
mental_vs_physical=int(input("Enter mental_vs_physical : "))
print("\n{Enter 0 for No\tEnter 1 for Yes}\n")
obs_consequence=int(input("Enter obs_consequence : "))


user_input_data = [[Age,Gender,self_employed,family_history,no_employees,remote_work,tech_company,benefits,care_options,seek_help,anonymity,leave,mental_health_consequence,phys_health_consequence,coworkers,supervisor,mental_vs_physical,obs_consequence]]
result = predict_output(user_input_data)
if result[0] == 0:
    print("no treatment reaquired\n\n")
else:
    print("yes treatment required\n\n")
# Out:
# Enter Age : 23
#
# {Enter 0 for Female	Enter 1 for Male	Enter 2 for others }
#
# Enter Gender : 0
#
# {Enter 0 for No	Enter 1 for Yes}
#
# Enter self_employed : 0
#
# {Enter 0 for No	Enter 1 for Yes}
#
# Enter family_history : 0
#
# {Enter 4 for no. of employee between 6-25
# Enter 5 for no. of employee more than 1000
# Enter 2 for no. of employee between 26-100
# Enter 1 for no. of employee between 100-500
# Enter 0 for no. of employee between 1-5
# Enter 3 for no. of employee between 500-1000}
#
# Enter no_employees : 0
#
# {Enter 0 for no and 1 for yes}
#
# remote_work : 0
#
# {Enter 0 for no and 1 for yes}
#
# Enter tech_company : 0
#
# {enter 0 for Don't know	 Enter 1 for No	Enter 2 for yes}
#
# enter benefits : 0
#
# {enter 0 for no	Enter 1 for Not sure	Enter 2 for yes}
#
# enter care_options : 0
#
# {enter 0 for Don't know	Enter 1 for No	Enter 2 for yes}
#
# enter seek_help : 0
#
# {enter 0 for Don't know	Enter 1 for No	Enter 2 for yes}
#
# anonymity : 0
#
# ...
